# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#import data customer

# %%
path='/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Original Data/customers.csv'

# %%
df=pd.read_csv(os.path.join(path))

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
df.shape
# Out:
# (206209, 10)

# %%
df.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
path='/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_merged_large.pkl'

# %%
df_1=pd.read_pickle(os.path.join(path))

# %%
df_1.shape
# Out:
# (32434489, 11)

# %%
#checking for duplicates

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 206204    False
# 206205    False
# 206206    False
# 206207    False
# 206208    False
# Length: 206209, dtype: bool

# %%
#renaming column

# %%
df.rename(columns = {'n_dependants' : 'children'}, inplace = True)

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    children fam_status  income
# 0         3    married  165665
# 1         0     single   59285
# 2         2    married   99568
# 3         0     single   42049
# 4         1    married   40374

# %%
#made the decision to drop the name columns(for analysis not neccessary and personal/confident data anyways)

# %%
df.drop(columns = ['First Name','Surnam'])
# Out:
#         user_id  Gender           STATE  Age date_joined  children fam_status  \
# 0         26711  Female        Missouri   48    1/1/2017         3    married
# 1         33890  Female      New Mexico   36    1/1/2017         0     single
# 2         65803    Male           Idaho   35    1/1/2017         2    married
# 3        125935  Female            Iowa   40    1/1/2017         0     single
# 4        130797  Female        Maryland   26    1/1/2017         1    married
# ...         ...     ...             ...  ...         ...       ...        ...
# 206204   168073  Female  North Carolina   44    4/1/2020         1    married
# 206205    49635    Male          Hawaii   62    4/1/2020         3    married
# 206206   135902  Female        Missouri   66    4/1/2020         2    married
# 206207    81095  Female      California   27    4/1/2020         1    married
# 206208    80148  Female        New York   55    4/1/2020         1    married
#
#         income
# 0       165665
# ...

# %%
df_cust=df.drop(columns = ['First Name','Surnam'])

# %%
#checking the key columns for later use

# %%
df['user_id'].value_counts(dropna=False)
# Out:
# user_id
# 26711     1
# 67322     1
# 173044    1
# 61044     1
# 98344     1
#          ..
# 146847    1
# 154991    1
# 172193    1
# 184326    1
# 80148     1
# Name: count, Length: 206209, dtype: int64

# %%
df_1['user_id'].value_counts(dropna=False)
# Out:
# user_id
# 201268    3725
# 129928    3638
# 164055    3061
# 186704    2936
# 176478    2921
#           ...
# 178594       3
# 201027       3
# 106736       3
# 119944       3
# 63995        3
# Name: count, Length: 206209, dtype: int64

# %%
df_cust.T
# Out:
#                0           1         2         3         4         5       \
# user_id         26711       33890     65803    125935    130797    133128
# Gender         Female      Female      Male    Female    Female    Female
# STATE        Missouri  New Mexico     Idaho      Iowa  Maryland  Kentucky
# Age                48          36        35        40        26        43
# date_joined  1/1/2017    1/1/2017  1/1/2017  1/1/2017  1/1/2017  1/1/2017
# children            3           0         2         0         1         2
# fam_status    married      single   married    single   married   married
# income         165665       59285     99568     42049     40374     49643
#
#                6               7         8         9       ...  \
# user_id        152052          168851     69965     82820  ...
# Gender           Male            Male      Male      Male  ...
# STATE         Montana  South Carolina     Texas  Virginia  ...
# ...

# %%
data_dict = df_cust.to_dict('index')

# %%
#checking for missing values

# %%
df_cust.isnull().sum()
# Out:
# user_id        0
# Gender         0
# STATE          0
# Age            0
# date_joined    0
# children       0
# fam_status     0
# income         0
# dtype: int64

# %%
#checking all columns

# %%
df_cust['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      104067
# Female    102142
# Name: count, dtype: int64

# %%
df_cust['STATE'].value_counts(dropna=False)
# Out:
# STATE
# Florida                 4044
# Colorado                4044
# Illinois                4044
# Alabama                 4044
# District of Columbia    4044
# Hawaii                  4044
# Arizona                 4044
# Connecticut             4044
# California              4044
# Indiana                 4044
# Arkansas                4044
# Alaska                  4044
# Delaware                4044
# Iowa                    4044
# Idaho                   4044
# Georgia                 4044
# Wyoming                 4043
# Mississippi             4043
# Oklahoma                4043
# Utah                    4043
# New Hampshire           4043
# Kentucky                4043
# Maryland                4043
# Rhode Island            4043
# Massachusetts           4043
# Michigan                4043
# New Jersey              4043
# Kansas                  4043
# South Dakota            4043
# Minnesota               4043
# Tennessee               4043
# New York                4043
# ...

# %%
df_cust['Age'].value_counts(dropna=False)
# Out:
# Age
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: count, Length: 64, dtype: int64

# %%
df_cust['date_joined'].value_counts(dropna=False)
# Out:
# date_joined
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: count, Length: 1187, dtype: int64

# %%
df_cust['children'].value_counts(dropna=False)
# Out:
# children
# 0    51602
# 3    51594
# 1    51531
# 2    51482
# Name: count, dtype: int64

# %%
df_cust['fam_status'].value_counts(dropna=False)
# Out:
# fam_status
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: count, dtype: int64

# %%
df_cust['income'].value_counts(dropna=False)
# Out:
# income
# 57192     10
# 95891     10
# 95710     10
# 97532      9
# 98675      9
#           ..
# 73141      1
# 71524      1
# 74408      1
# 44780      1
# 148828     1
# Name: count, Length: 108012, dtype: int64

# %%
#looking for mixed data

# %%
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].map(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)

# %%
path='/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_ords_frequencies.pkl'

# %%
df_ords_prods=pd.read_pickle(os.path.join(path))

# %%
df_merged = df_ords_prods.merge(df_cust, on = 'user_id')

# %%
print("Columns in df_ords_prods:", df_ords_prods.columns.tolist())
# Out:
# Columns in df_ords_prods: ['Unnamed: 0_x', 'order_id', 'user_id', 'order_number', 'orders_day_of_week', 'order_time', 'days_since_prior_order', 'product_id', 'add_to_cart_order', 'reordered', '_merge', 'Unnamed: 0_y', 'product_name', 'aisle_id', 'department_id', 'prices', 'merge_indicator', 'price_range', 'price_range_loc', 'busiest_day', 'busiest_days', 'order_time_loc', 'time_of_order', 'max_order', 'loyalty_flag']

# %%
print("Columns in df_cust:", df_cust.columns.tolist())
# Out:
# Columns in df_cust: ['user_id', 'Gender', 'STATE', 'Age', 'date_joined', 'children', 'fam_status', 'income']

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             0   2539329        1             1                   2
# 2             0   2539329        1             1                   2
# 3             0   2539329        1             1                   2
# 4             0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered  ...   time_of_order  max_order  loyalty_flag  Gender    STATE  \
# ...

# %%
df_merged.shape
# Out:
# (32404859, 32)

# %%
df_merged.to_pickle(os.path.join(path,'/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_ords_cust_merge.pkl'))
