# %% [raw]
# #import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #import pickle & csv for merge

# %%
path='/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_merged_large.pkl'

# %%
df_orders_products_combined=pd.read_pickle(os.path.join(path))

# %%
#Check shape of imported data

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
#Repeat procedure

# %%
path='/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_clean_no_dups.csv'

# %%
df_prods=pd.read_csv(os.path.join(path),index_col=False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
#check for shared column to merge on

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
#merge dfs

# %%
df_ords_prods_merge = df_orders_products_combined.merge(df_prods, on='product_id', indicator='merge_indicator')

# %% [markdown]
# Checking if the merge worked
# head to see if the indicator column checks out
# and value_counts()for consistency of the merge

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             0   2539329        1             1                   2
# 2             0   2539329        1             1                   2
# 3             0   2539329        1             1                   2
# 4             0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered _merge  Unnamed: 0_y                             product_name  \
# ...

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#export merged df as pickle (because of its size)

# %%
df_ords_prods_merge.to_pickle(os.path.join(path,'/Users/Pc-Neumann/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/df_ords_prods_merge.pkl'))

# %%
#for several days my computer couldn't handle the data , I tried but it crashed. Thankfully for whatever reason it worked now.
